# %%
#https://losskatsu.github.io/programming/py-crawling01/#123-%EC%98%88%EC%99%B8-%EC%B2%98%EB%A6%AC

# %%
import re
import requests      #웹 페이지의 HTML을 가져오는 모듈
from bs4 import BeautifulSoup        #HTML을 파싱하는 모듈

# %%
##header 입력정보
import ssl
import requests
import urllib
from bs4 import BeautifulSoup
import os
import time
import ssl
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

##open chrome browser
driver = webdriver.Chrome("/data/kjyon/chromedriver.exe")
driver.implicitly_wait(3)

##delete checking headers
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE


driver.get('http://www.useragentstring.com/')

# %%
#PC 접속
#Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36

# %%
url = 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004605101'
headers = {'User-Agent' : 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

# %%
#requests 라이브러리를 활용한 HTML 페이지 요청,res 갹체에 HTML 데이터가 저장되고, res.content로 데이터 추출
#HTML 페이지 파싱 BeautifulSoup(HTML 데이터, 파싱 방법)



res = requests.get(url, headers = headers)
soup = BeautifulSoup(res.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="width=1106" name="viewport">
# <title>중견건설사 '페이퍼 컴퍼니 꼼수'로 LH 공공택지 싹쓸이 : 네이버 뉴스</title>
# <meta content="파이낸셜뉴스 : 네이버뉴스" property="me2:post_tag">
# <meta content="파이낸셜뉴스" property="me2:category1">
# <meta content="경제" property="me2:category2"/>
# <meta content="https://imgnews.pstatic.net/image/014/2021/03/22/0004605101_001_20210322165949615.jpg" property="me2:image"/>
# <meta content="중견건설사 '페이퍼 컴퍼니 꼼수'로 LH 공공택지 싹쓸이" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;oid=014&amp;aid=0004605101&amp;sid1=001" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/014/2021/03/22/0004605101_001_20210322165949615.jpg" property="og:image"/>
# ...

# %%
print(soup.p)
# Out:
# <p class="head_channel_layer" style="display: none;">
# <span class="head_channel_layer_text">해당 언론사가 주요기사로<br/>직접 선정한 기사입니다.</span>
# <a class="head_channel_layer_link" href="https://news.naver.com/main/static/channelPromotion.html" target="_blank">언론사 편집판 바로가기</a>
# <button class="head_channel_layer_close" type="button">닫기</button>
# </p>

# %%
print(soup.p.string)
# Out:
# None

# %%
print(soup.p.get_text())
# Out:
# 해당 언론사가 주요기사로직접 선정한 기사입니다.
# 언론사 편집판 바로가기
# 닫기

# %%
print(soup.find('p'))
# Out:
# <p class="head_channel_layer" style="display: none;">
# <span class="head_channel_layer_text">해당 언론사가 주요기사로<br/>직접 선정한 기사입니다.</span>
# <a class="head_channel_layer_link" href="https://news.naver.com/main/static/channelPromotion.html" target="_blank">언론사 편집판 바로가기</a>
# <button class="head_channel_layer_close" type="button">닫기</button>
# </p>

# %%
print(soup.find_all("p"))
# Out:
# [<p class="head_channel_layer" style="display: none;">
# <span class="head_channel_layer_text">해당 언론사가 주요기사로<br/>직접 선정한 기사입니다.</span>
# <a class="head_channel_layer_link" href="https://news.naver.com/main/static/channelPromotion.html" target="_blank">언론사 편집판 바로가기</a>
# <button class="head_channel_layer_close" type="button">닫기</button>
# </p>, <p class="tts_save__text">설정을 저장하시겠습니까?</p>, <p class="media_end_head_fontsize_linklayer_txt"><strong>나눔고딕</strong> 폰트가 설치되어있지 않습니다.<br/><em>나눔 폰트</em>를 설치하러 가시겠습니까?</p>, <p class="guide_categorization_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>, <p class="section_sub_txt">오전 8시~오전 9시까지 집계한 결과입니다.</p>, <p class="section_sub_txt">오전 8시~오전 9시까지 집계한 결과입니다.</p>, <p class="blind">상처 없는 댓글 세상 만들기에 많은 참여 부탁드립니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
print(soup.h1)
# Out:
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>

# %%
#태그는 보통 트리구조로 위계가 있기 때문에 하위 항목을 모두 뽑아오고 싶다면 .children을 사용

for child in soup.ul.children:
    print(child)
# Out:
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
#
#
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
#
#
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
#
#
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>

# %%
#지정된 태그의 상위 항목을 가져오기 .parents를 사용
for parent in soup.ul.parents:
    print(parent)
# Out:
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# ...

# %%
#div 하위 요소 출력하려면
for d in soup.div.children:
    print(d)
# Out:
# <div id="da_base"></div>
#
#
# <div id="da_stake"></div>
#
#
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# ...

# %%
#h1부터 h9까지 

import re
soup.find_all(re.compile("h[1-9]"))
# Out:
# [<h1>
#  <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
#  <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
#  </h1>,
#  <h3 id="articleTitle">중견건설사 '페이퍼 컴퍼니 꼼수'로 LH 공공택지 싹쓸이</h3>,
#  <h3>파이낸셜뉴스 관련뉴스<span>해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span></h3>,
#  <h4>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  										경제 속보 <span class="fs11"><a class="c6 nclicks(abt_seclist)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=101">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  기사목록 전체보기</a></span></h4>,
#  <h4><em>파이낸셜뉴스</em> 랭킹 뉴스</h4>,
#  <h4>분야별 주요뉴스</h4>,
#  <h4>언론사별 가장 많이 본 뉴스</h4>,
#  <h5 class="blind">욕설 댓글 리마인드 팝업</h5>]

# %%
 #<ol>이든 <ul>이든 뭐든 포함된 리스트를 긁어오기

import re
soup.find_all(re.compile("[ou]l"))
# Out:
# [<ul class="snb_related_service">
#  <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
#  <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
#  <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
#  <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
#  </ul>,
#  <ul>
# ...

# %%
#필요 데이터 검색

title = soup.find('title')

# %%
print(title)
# Out:
# <title>'페이퍼 컴퍼니 꼼수'로 LH 공공택지, 호반건설이 휩쓸었다 : 네이버 뉴스</title>

# %%
print(title.get_text())
# Out:
# '페이퍼 컴퍼니 꼼수'로 LH 공공택지, 호반건설이 휩쓸었다 : 네이버 뉴스

# %%
#태그를 통한 검색
t1 = soup.find('h3')

# %%
print(t1.get_text())
# Out:
# '페이퍼 컴퍼니 꼼수'로 LH 공공택지, 호반건설이 휩쓸었다

# %%
t2 = soup.find(id = 'articleTitle')

# %%
print(t2.get_text())
# Out:
# '페이퍼 컴퍼니 꼼수'로 LH 공공택지, 호반건설이 휩쓸었다

# %%
content = soup.find(id = 'articleBodyContents' )

# %%
print(content.get_text())

# // flash 오류~~~
# Out:
#
#
#
#
#
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
#
#
# ...

# %%
links = soup.select('a[href]')

# %%
print(links)
# Out:
# [<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>, <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>, <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>, <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>, <a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a>, <a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a>, <a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a>, <a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/imag
# ...

# %%
for link in links:
    print(link['href'])
# Out:
# #lnb
# #main_content
# https://www.naver.com/
# /
# https://entertain.naver.com/home
# https://sports.news.naver.com
# https://newsstand.naver.com
# https://weather.naver.com
# /main/home.nhn
# /main/list.nhn?mode=LSD&mid=sec&sid1=001
# /main/main.nhn?mode=LSD&mid=shm&sid1=100
# /main/main.nhn?mode=LSD&mid=shm&sid1=101
# /main/main.nhn?mode=LSD&mid=shm&sid1=102
# /main/main.nhn?mode=LSD&mid=shm&sid1=103
# /main/main.nhn?mode=LSD&mid=shm&sid1=104
# /main/main.nhn?mode=LSD&mid=shm&sid1=105
# /main/opinion/home.nhn
# /main/photo/index.nhn?mid=pho
# /main/tv/index.nhn?mid=tvh
# /main/ranking/popularDay.nhn?mid=etc&sid1=111
# https://news.naver.com/main/factcheck/main.nhn?section=%C4%DA%B7%CE%B3%AA%B9%E9%BD%C5
# https://media.naver.com/channel/settings.nhn
# https://news.naver.com/main/officeList.nhn
# https://newslibrary.naver.com/search/searchByDate.nhn
# http://www.fnnews.com/
# https://news.naver.com/main/static/channelPromotion.html
# http://www.fnnews.com/news/202103212231380091
# ...

# %%
for link in links:
    print(link.get_text())
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# NAVER
# 뉴스
#
#
#
#
# 뉴스홈
# 속보선택됨
# 정치
# 경제
# 사회
# 생활/문화
# 세계
# IT/과학
# 오피니언
# 포토
# TV
# 랭킹뉴스
# 코로나19 팩트체크
#
# 언론사 구독
#
# 언론사 뉴스
#
# 라이브러리
#
#
# 언론사 편집판 바로가기
# 기사원문
# 스크랩
# 선택된 성별남성
# 여성
# 느림
# 선택된 속도보통
# 빠름
# 확인
# 취소
#
#
# 좋아요
#
# 좋아요 평가하기
# 공감
#
#
# 좋아요
# 0
#
#
# 훈훈해요
# 0
#
#
# 슬퍼요
# 0
#
#
# 화나요
# 0
#
#
# 후속기사 원해요
# 0
#
#
# 댓글
#
# 요약봇
# 도움말
#
# 만족
#
#
# 보통
#
#
# 불만족
#
# 닫기
# 글자 크기 변경하기
# 가1단계
# 가2단계
# 가3단계
# 가4단계
# 가5단계
# 굴림
# 돋움
# 맑은고딕
# 나눔고딕
# 닫기
# 예
# 아니오
# 닫기
# 인쇄하기
#
#
# 보내기
#
# ▶ 헉! 소리나는 스!토리 뉴스 [헉스]
# ▶ '아는 척'하고 싶은 당신을 위한 [두유노우]
# ▶ 날로먹고 구워먹는 금융이슈 [파인애플]
# 이 기사는 언론사에서 경제 섹션으로 분류했습니다.
# 닫기
#
# 좋아요
# 0
#
#
# 훈훈해요
# 0
#
#
# 슬퍼요
# 0
#
#
# 화나요
# 0
#
#
# 후속기사 원해요
# 0
#
#
#
# 이 기사를 추천합니다
#
#
#
#
# 보내기
#
# "남편에게 새로운 여자가 둘이나.." 前 MBC 아나운서의 고백
# 유흥주점서 '여종업원과 술자리' 유노윤호, 결국..
# 주식으로 3개월만에 15억 날린 개그맨, 3년 뒤.. 초대박
# '갑자기 이혼' 女배우 뜻밖의 고백 "동료 남편이.."
# 노래주점 女주인과 땅보러 간 男, 공터에 차 세우고 한 짓이..
#  기사 모아보기
#
# 			파이낸셜뉴스 기사제공
#
#
# 신문
# 						파이낸셜뉴스  신문게재기사만
#
# 인쇄
# 스크랩
#
#
#
# ...

# %%
date = soup.select('.t11')

# %%
print(date)
# Out:
# [<span class="t11">2021.03.22. 오전 5:11</span>, <span class="t11">2021.03.22. 오전 6:36</span>]

# %%
import time

def get_news(n_url):
    news_detail = []
    time.sleep(0.5)

    headers = {'User-Agent' : 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

    req2 = requests.get(n_url, headers = headers)
    soup2 = BeautifulSoup(req2.content, 'html.parser')

    title = soup2.select('h3#articleTitle')[0].text #대괄호는 h3#articleTitle 인 것중 첫번째 그룹만 가져오겠다.
    news_detail.append(title)

    pdate = soup2.select('.t11')[0].get_text()[:11]
    news_detail.append(pdate)

    
    _text = soup2.select('#articleBodyContents')[0].get_text().replace('\n', " ")
    text = _text.replace('\t', '')
    text2 = text.replace('// flash 오류를 우회하기 위한 함수 추가 function _flash_removeCallback() {}', "")
    news_detail.append(text2.strip())

    news_detail.append(n_url)

    company = soup2.select('#footer address')[0].a.get_text()
    news_detail.append(company)
    
    return news_detail

# %%
url2= 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=629&aid=0000073058'

# %%
get_news(url2)
# Out:
# ['DL이앤씨, 볼보그룹코리아와 스마트 건설 기술 개발한다',
#  '2021.03.22.',
# ...
